# %%
import modals
import modals.columns
import modals.db
db = modals.db.DataBase("app")
columns_map = {"id": modals.columns.Column("id", 1, False),"name":modals.columns.Column("name", 2, False),"job":modals.columns.Column("job",2,False),"age":modals.columns.Column("age", 1, False),"is_cool":modals.columns.Column("is_cool", 1, False)} 
columns_list =columns_map.keys()
table = db.create_tables("test", columns_list, columns_map)
# Out:
# total tables in the db are []
# Encoded TLV: [2, 2, 0, 0, 0, 105, 100] for value id
# Encoded TLV: [5, 4, 0, 0, 0, 1, 0, 0, 0] for value 1
# Encoded TLV: [4, 1, 0, 0, 0, 0] for value False
# Column TLV: [99, 0, 0, 0, 22, 0, 0, 0, 2, 2, 0, 0, 0, 105, 100, 5, 4, 0, 0, 0, 1, 0, 0, 0, 4, 1, 0, 0, 0, 0] (len=30)
# The value b'c\x00\x00\x00\x16\x00\x00\x00\x02\x02\x00\x00\x00id\x05\x04\x00\x00\x00\x01\x00\x00\x00\x04\x01\x00\x00\x00\x00' was wrote to the colwriter of length 30 bytes with total data being 30
# Encoded TLV: [2, 4, 0, 0, 0, 110, 97, 109, 101] for value name
# Encoded TLV: [5, 4, 0, 0, 0, 2, 0, 0, 0] for value 2
# Encoded TLV: [4, 1, 0, 0, 0, 0] for value False
# Column TLV: [99, 0, 0, 0, 24, 0, 0, 0, 2, 4, 0, 0, 0, 110, 97, 109, 101, 5, 4, 0, 0, 0, 2, 0, 0, 0, 4, 1, 0, 0, 0, 0] (len=32)
# The value b'c\x00\x00\x00\x18\x00\x00\x00\x02\x04\x00\x00\x00name\x05\x04\x00\x00\x00\x02\x00\x00\x00\x04\x01\x00\x00\x00\x00' was wrote to the colwriter of length 32 bytes with total data being 32
# Encoded TLV: [2, 3, 0, 0, 0, 106, 111, 98] for value job
# Encoded TLV: [5, 4, 0, 0, 0, 2, 0, 0, 0] for value 2
# Encoded TLV: [4, 1, 0, 0, 0, 0] for value False
# Column TLV: [99, 0, 0, 0, 23, 0, 0, 0, 2, 3, 0, 0, 0, 106, 111, 98, 5, 4, 0, 0, 0, 2, 0, 0, 0, 4, 1, 0, 0, 0, 0] (len=31)
# The value b'c\x00\x00\x00\x17\x00\x00\x00\x02\x03\x00\x00\x00job\x05\x04\x00\x00\x00\x02\x00\x00\x00\x04\x01\x00\x00\x00\x00' was wrote to the colwriter of length 31 bytes with total data being 31
# Encoded TLV: [2, 3, 0, 0, 0, 97, 103, 101] for value age
# Encoded TLV: [5, 4, 0, 0, 0, 1, 0, 0, 0] for value 1
# Encoded TLV: [4, 1, 0, 0, 0, 0] for value False
# Column TLV: [99, 0, 0, 0, 23, 0, 0, 0, 2, 3, 0, 0, 0, 97, 103, 101, 5, 4, 0, 0, 0, 1, 0, 0, 0, 4, 1, 0, 0, 0, 0] (len=31)
# The value b'c\x00\x00\x00\x17\x00\x00\x00\x02\x03\x00\x00\x00age\x05\x04\x00\x00\x00\x01\x00\x00\x00\x04\x01\x00\x00\x00\x00' was wrote to the colwriter of length 31 bytes with total data being 31
# Encoded TLV: [2, 7, 0, 0, 0, 105, 115, 95, 99, 111, 111, 108] for value is_cool
# Encoded TLV: [5, 4, 0, 0, 0, 1, 0, 0, 0] for value 1
# Encoded TLV: [4, 1, 0, 0, 0, 0] for value False
# Column TLV: [99, 0, 0, 0, 27, 0, 0, 0, 2, 7, 0, 0, 0, 105, 115, 95, 99, 111, 111, 108, 5, 4, 0, 0, 0, 1, 0, 0, 0, 4, 1, 0, 0, 0, 0] (len=35)
# The value b'c\x00\x00\x00\x1b\x00\x00\x00\x02\x07\x00\x00\x00is_cool\x05\x04\x00\x00\x00\x01\x00\x00\x00\x04\x01\x00\x00\x00\x00' was wrote to the colwriter of length 35 bytes with total data being 35

# %%
0.0026617050170898438*1000
# Out:
# 2.6617050170898438

# %%
0.03711891174316406*1000
# Out:
# 37.11891174316406
